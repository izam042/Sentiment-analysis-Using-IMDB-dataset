# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-00b0feaa-9ee7-464c-ae4e-70295a4c2424" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-00b0feaa-9ee7-464c-ae4e-70295a4c2424">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os
import re
import pyprind
import pandas as pd
import sys
import tarfile
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from nltk.stem.porter import PorterStemmer
import nltk
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV

basepath = 'aclImdb'
labels = {'pos': 1, 'neg': 0}
pbar = pyprind.ProgBar(50000, stream=sys.stdout)


reviews = []

for s in ('test', 'train'):
  for l in ('pos', 'neg'):
    path = os.path.join(basepath, s, l)

    for file in sorted(os.listdir(path)):
      with open(os.path.join(path, file), 'r', encoding='utf-8') as infile:
        txt = infile.read()

      reviews.append({'review': txt, 'sentiment': labels[l]})
      pbar.update()


df = pd.DataFrame(reviews)

np.random.seed(0)
df = df.reindex(np.random.permutation(df.index))

df.to_csv('movie_data.csv', index=False, encoding='utf-8')

df = pd.read_csv('movie_data.csv' , encoding = 'utf-8')

df = df.rename(columns={"0": "review", "1": "sentiment"})

count = CountVectorizer()
docs = np.array(['The sun is shining',
                 'The weather is sweet',
                 'The sun is shining, the weather is sweet, and one and one is two'])
bag = count.fit_transform(docs)

def preprocessor(text):
  text = re.sub('<[^>]*>', '', text)
  emoticons = re.findall('(?::|;|=)(?:-)?(?:\)|\(|D|P)', text)
  text = re.sub('[\W]+', ' ', text.lower()) +\
    ' '.join(emoticons)

  return text


df['review'] = df['review'].apply(preprocessor)

porter = PorterStemmer()

def tokenizer_porter(text):
  return ([porter.stem(word) for word in text.split()])


def tokenizer(text):
  return text.split()

nltk.download('stopwords')

stop = nltk.corpus.stopwords.words('english')

[w for w in tokenizer_porter('a runner likes'' running and runs a lot')
 if w not in stop]


X_train = df.loc[:25000, 'review'].values
y_train = df.loc[:25000, 'sentiment'].values
X_test = df.loc[25000:, 'review'].values
y_test = df.loc[25000:, 'sentiment'].values

tfidf = TfidfVectorizer(strip_accents=None,
                        lowercase=False,
                        preprocessor=None)

small_param_grid= [ {
    'vect__ngram_range': [(1,1)],
    'vect__stop_words': [None],
    'vect__tokenizer': [tokenizer_porter,tokenizer],
}, {
    'vect__ngram_range': [(1,1)],
    'vect__stop_words': [stop, None],
    'vect__tokenizer': [tokenizer],
    'clf__penalty': [ 'l2'],
    'clf__C': [1.0, 10.0, 100.0],
} ]


lr_tfidf = Pipeline([('vect', tfidf),
                     ('clf', LogisticRegression(solver ='liblinear' ,random_state=0))])

gs_lr_tfidf = GridSearchCV(lr_tfidf, param_grid=small_param_grid,
                           scoring='accuracy',
                           cv=5,
                           verbose=1,
                           n_jobs=-1)
gs_lr_tfidf.fit(X_train,y_train)

print(f'CV Accuracy: {gs_lr_tfidf.best_score_:.3f}')
print(f'Test Accuracy: {gs_lr_tfidf.best_estimator_.score(X_test, y_test):.3f}')
# Out:
# <>:54: SyntaxWarning: invalid escape sequence '\)'
# <>:55: SyntaxWarning: invalid escape sequence '\W'
# <>:54: SyntaxWarning: invalid escape sequence '\)'
# <>:55: SyntaxWarning: invalid escape sequence '\W'
# /tmp/ipython-input-1829625632.py:54: SyntaxWarning: invalid escape sequence '\)'
#   emoticons = re.findall('(?::|;|=)(?:-)?(?:\)|\(|D|P)', text)
# /tmp/ipython-input-1829625632.py:55: SyntaxWarning: invalid escape sequence '\W'
#   text = re.sub('[\W]+', ' ', text.lower()) +\
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# /usr/local/lib/python3.12/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# CV Accuracy: 0.897
# Test Accuracy: 0.899

# %% [markdown]
# **Reasoning**:
# The previous code block failed due to a `SyntaxError` because a string concatenation was split across lines without proper parentheses or line continuation. I need to fix the `preprocessor` function to correctly concatenate the strings.
